# %% [markdown]
# ### Hi, this is Abababa's blog~

# %%
import numpy as np 

a = np.random.random((10, 10))
b = np.random.random((10, 10))
print(a @ b)
# Out:
# [[2.66354885 2.6919614  4.92906643 2.92820551 3.75657326 3.76445048
#   2.64840008 2.52284859 2.40790891 4.14235715]
#  [2.63357437 2.15937265 4.70047502 2.80895378 3.87726256 4.20296755
#   2.87345109 2.35604229 2.63402634 3.87897227]
#  [1.57009035 2.28599982 2.83676297 1.57009167 2.34277157 1.74977455
#   1.74456503 1.45921685 1.71547574 2.22689317]
#  [1.88123119 1.55306681 2.77266269 1.43564185 2.32823673 2.02433683
#   1.69097322 1.60674332 1.7667407  2.62027646]
#  [2.55030164 3.34227344 5.26716862 3.28457333 4.64136204 4.70729084
#   3.37233971 2.52450484 3.0313266  4.47833773]
#  [1.50128546 2.40736577 3.3816147  2.05473987 3.00424024 3.02505241
#   2.29331342 1.53687934 2.02856606 2.77796865]
#  [1.41546569 2.59965395 3.13801462 1.93414682 3.05677265 2.86674562
#   2.22798917 1.8020773  2.28744005 3.05632464]
#  [1.61937627 2.20726168 2.82898143 1.46005156 2.3876552  2.06918628
#   1.66536363 1.50178476 2.13479595 2.22078868]
# ...
